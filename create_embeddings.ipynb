# %%
from transformers import CLIPProcessor, CLIPModel
import torch
import sqlite3
import time
from enum import Enum
from typing import List, Dict, Optional, Tuple
import logging
import mwclient
import hashlib
import urllib.parse

# %%
# Database handling
class EmbeddingsDatabase:
    def __init__(self, db_path: str = "wiki_embeddings.db"):
        self.db_path = db_path
        self.setup_database()
    
    def setup_database(self):
        """Create database tables."""
        with sqlite3.connect(self.db_path) as conn:
            conn.execute("""
                CREATE TABLE IF NOT EXISTS embeddings (
                    article_id TEXT PRIMARY KEY,
                    title TEXT,
                    url TEXT,
                    embedding BLOB,
                    processed_date TEXT,
                    hash TEXT
                )
            """)
            conn.execute("""
                CREATE TABLE IF NOT EXISTS failed_articles (
                    article_id TEXT PRIMARY KEY,
                    title TEXT,
                    error_message TEXT,
                    attempt_date TEXT
                )
            """)
    
    def store_embedding(self, article_id: str, title: str, url: str, embedding: bytes, hash_val: str):
        """Store a single embedding in the database."""
        with sqlite3.connect(self.db_path) as conn:
            conn.execute(
                """
                INSERT OR REPLACE INTO embeddings 
                (article_id, title, url, embedding, processed_date, hash)
                VALUES (?, ?, ?, ?, datetime('now'), ?)
                """,
                (article_id, title, url, embedding, hash_val)
            )
    
    def store_failed_article(self, article_id: str, title: str, error: str):
        """Store information about failed article processing."""
        with sqlite3.connect(self.db_path) as conn:
            conn.execute(
                """
                INSERT OR REPLACE INTO failed_articles 
                (article_id, title, error_message, attempt_date)
                VALUES (?, ?, ?, datetime('now'))
                """,
                (article_id, title, error)
            )

# Wikipedia API handling
class WikipediaArticleFetcher:
    def __init__(self, user_agent: str):
        self.site = mwclient.Site('en.wikipedia.org', clients_useragent=user_agent)
        self.logger = logging.getLogger(__name__)
    
    def get_vital_articles(self, level: int = 4) -> List[Dict]:
        """Get vital articles at specified level."""
        if not isinstance(level, int) or level < 1 or level > 5:
            raise ValueError("Level must be an integer between 1 and 5")
        
        article_titles = set()
        
        def process_article_lines(text: str, marker: str = '*') -> None:
            for line in text.split('\n'):
                if line.startswith(marker) and '[[' in line and ']]' in line:
                    start = line.find('[[') + 2
                    end = line.find(']]')
                    article_title = line[start:end]
                    if '|' in article_title:
                        article_title = article_title.split('|')[0]
                    article_titles.add(article_title)
        
        if level in [4, 5]:
            main_page = self.site.pages[f'Wikipedia:Vital articles/Level/{level}']
            vital_article_categories = []
            
            for line in main_page.text().split('\n'):
                if line.startswith('|') and '[[' in line and ']]' in line:
                    start = line.find('[[') + 2
                    end = line.find(']]')
                    category = line[start:end].split('|')[0]
                    vital_article_categories.append(category)
            
            for category in vital_article_categories:
                category_page = self.site.pages[category]
                process_article_lines(category_page.text(), marker='#')
        else:
            page = self.site.pages[f'Wikipedia:Vital articles/Level/{level}']
            process_article_lines(page.text())

        return self._convert_titles_to_articles(sorted(article_titles))
    
    def get_good_articles(self) -> List[Dict]:
        """
        Get all articles that have been marked as good articles from
        the page https://en.wikipedia.org/wiki/Wikipedia:Good_articles/all
        """

        good_article_base = 'Wikipedia:Good_articles'
        # start by getting all categories
        categories = []
        counter = 0
        page = self.site.pages[good_article_base + '/all']
        for line in page.text().split('\n'):
                #print(line)
                if line.startswith('*') and '[[' in line and ']]' in line:
                    start = line.find('[[') + 2
                    end = line.find(']]')
                    category = line[start:end].split('|')[1]
                    categories.append(category)

        # get all articles in the categories
        articles = []
        for category in categories:
            page = self.site.pages[f'{good_article_base}/{category}']
            for line in page.text().split('\n'):
                if '[[' in line and ']]' in line and '|' not in line:
                    start = line.find('[[') + 2
                    end = line.find(']]')
                    article = line[start:end]
                    articles.append(article)
                    counter += 1
                    if counter % 500 == 0:
                        print(f"Grabbed {counter} good article titles")
        
        return self._convert_titles_to_articles(sorted(articles))
    
    def get_a_class_articles(self) -> List[Dict]:
        """Get all A-Class articles."""
        articles = []
        counter = 0
        for category in self.site.categories['A-Class_articles'].members():
            if category.length > 0:
                for member in category.members():
                    title = member.name.split(':')[1]
                    articles.append(title)
                    counter += 1
                    if counter % 500 == 0:
                        print(f"Grabbed {counter} A-Class article titles")
        return self._convert_titles_to_articles(sorted(articles))

    def get_articles_from_titles(self, titles: List[str]) -> List[Dict]:
        """Get articles from a list of titles."""
        return self._convert_titles_to_articles(titles)
    
    def _convert_titles_to_articles(self, titles: List[str]) -> List[Dict]:
        """Convert titles to article dictionaries with metadata."""
        articles = []
        for i in range(0, len(titles), 50):
            batch_titles = titles[i:i + 50]
            result = self.site.api('query', 
                                format='json',
                                titles='|'.join(batch_titles),
                                redirects=1)
            
            if 'query' in result and 'pages' in result['query']:
                for page_id, page_data in result['query']['pages'].items():
                    if 'missing' not in page_data and 'invalid' not in page_data:
                        title = page_data['title']
                        title_encoded = urllib.parse.quote(title.replace(' ', '_'))
                        articles.append({
                            'id': str(page_id),
                            'title': title,
                            'url': f"https://en.wikipedia.org/wiki/{title_encoded}"
                        })
            time.sleep(0.01)
        return articles
    
    def get_article_content(self, articles: List[Dict]) -> List[Tuple[Dict, str, str]]:
        """Fetch content for a batch of articles."""
        results = []
        for i in range(0, len(articles), 50):
            chunk = articles[i:i + 50]
            titles = '|'.join(article['title'] for article in chunk)
            
            params = {
                'format': 'json',
                'prop': 'extracts',
                'exintro': True,
                'explaintext': True,
                'redirects': 1,
                'titles': titles
            }
            
            result = self.site.api('query', **params)
            
            if 'query' in result and 'pages' in result['query']:
                for page_id, page_data in result['query']['pages'].items():
                    matching_article = next(
                        (a for a in chunk if str(page_data.get('pageid')) == a['id']),
                        None
                    )
                    
                    if matching_article:
                        content = page_data.get('extract', '').strip()
                        if not content:
                            content = page_data.get('title', matching_article['title'])
                        
                        if content:
                            hash_val = hashlib.sha256(content.encode()).hexdigest()
                            results.append((matching_article, content, hash_val))
            
            time.sleep(0.01)
        
        return results

# Embedding generation
class EmbeddingGenerator:
    def __init__(self, model_name: str = "openai/clip-vit-base-patch32"):
        self.device = "cuda" if torch.cuda.is_available() else "mps" if torch.backends.mps.is_available() else "cpu"
        self.model = CLIPModel.from_pretrained(model_name).to(self.device)
        self.processor = CLIPProcessor.from_pretrained(model_name)
    
    def generate_embeddings(self, texts: List[str]) -> torch.Tensor:
        """Generate embeddings for a list of texts."""
        with torch.no_grad():
            inputs = self.processor(
                text=texts,
                return_tensors="pt",
                padding=True,
                truncation=True,
                max_length=77
            )
            text_features = self.model.get_text_features(
                **{k: v.to(self.device) for k, v in inputs.items()}
            )
            return text_features / text_features.norm(dim=-1, keepdim=True)


class ArticleSource(Enum):
    VITAL = "vital"
    GOOD = "good" 
    CUSTOM = "custom"
    A_CLASS = "a_class"

# Main orchestrator
class WikiEmbeddingsOrchestrator:
    def __init__(self, 
                 model_name: str = "openai/clip-vit-base-patch32",
                 db_path: str = "wiki_embeddings.db",
                 batch_size: int = 32,
                 user_agent: str = 'clip_embedding_wikipedia/0.0 (https://calebkruse.com/; caleb.krs@gmail.com)'
    ):
        # Setup logging
        logging.basicConfig(
            level=logging.INFO,
            format='%(asctime)s - %(levelname)s - %(message)s',
            handlers=[
                logging.FileHandler('wiki_embeddings.log'),
                logging.StreamHandler()
            ]
        )
        self.logger = logging.getLogger(__name__)
        
        # Initialize components
        self.batch_size = batch_size
        self.db = EmbeddingsDatabase(db_path)
        self.wiki_fetcher = WikipediaArticleFetcher(user_agent)
        self.embedding_generator = EmbeddingGenerator(model_name)

    def _get_articles_from_source(self, 
                                source: ArticleSource,
                                vital_level: Optional[int] = None,
                                custom_titles: Optional[List[str]] = None) -> List[Dict]:
        """Get articles based on the specified source type."""
        if source == ArticleSource.VITAL:
            if not vital_level or not (1 <= vital_level <= 5):
                raise ValueError("Vital articles require a level between 1 and 5")
            return self.wiki_fetcher.get_vital_articles(level=vital_level)
        
        elif source == ArticleSource.GOOD:
            return self.wiki_fetcher.get_good_articles()
        
        elif source == ArticleSource.CUSTOM:
            if not custom_titles:
                raise ValueError("Custom article source requires a list of titles")
            return self.wiki_fetcher.get_articles_from_titles(custom_titles)
        
        elif source == ArticleSource.A_CLASS:
            return self.wiki_fetcher.get_a_class_articles()
        
        raise ValueError(f"Unknown article source: {source}")

    def process_batch(self, articles: List[Dict]):
        """Process a batch of articles."""
        try:
            # Fetch article content
            article_data = self.wiki_fetcher.get_article_content(articles)
            
            if not article_data:
                self.logger.warning("No valid content found in batch")
                return
            
            # Split data
            valid_articles, contents, hashes = zip(*article_data)
            
            # Generate embeddings
            embeddings = self.embedding_generator.generate_embeddings(contents)
            
            # Store results
            for article, embedding, hash_val in zip(valid_articles, embeddings, hashes):
                self.db.store_embedding(
                    article['id'],
                    article['title'],
                    article['url'],
                    embedding.cpu().numpy().tobytes(),
                    hash_val
                )
                
        except Exception as e:
            self.logger.error(f"Batch processing error: {str(e)}")
            for article in articles:
                self.db.store_failed_article(article['id'], article['title'], str(e))

    def generate_embeddings(self,
                          source: ArticleSource,
                          vital_level: Optional[int] = None,
                          custom_titles: Optional[List[str]] = None):
        """Generate embeddings for articles from the specified source."""
        try:
            articles_to_process = self._get_articles_from_source(
                source=source,
                vital_level=vital_level,
                custom_titles=custom_titles
            )
            
            if not articles_to_process:
                self.logger.error("No articles found")
                return
            
            # Process in batches
            total_articles = len(articles_to_process)
            self.logger.info(f"Found {total_articles} articles to process")
            
            for i in range(0, total_articles, self.batch_size):
                batch = articles_to_process[i:i + self.batch_size]
                self.process_batch(batch)
                self.logger.info(f"Processed {min(i + self.batch_size, total_articles)}/{total_articles} articles")
                
        except KeyboardInterrupt:
            self.logger.info("Interrupted by user. Saving progress...")
        except Exception as e:
            self.logger.error(f"Fatal error: {str(e)}")

# %%
def get_a_class_articles():
    site = mwclient.Site('en.wikipedia.org', clients_useragent='clip_embedding_wikipedia/0.0 (https://calebkruse.com/; caleb.krs@gmail.com)')
    articles = []
    counter = 0
    for category in site.categories['A-Class_articles'].members():
        #print(category.name)
        if category.length > 0:
            for member in category.members():
                title = member.name.split(':')[1]
                articles.append(title)
                counter += 1
                if counter % 500 == 0:
                    print(f"Grabbed {counter} A-Class article titles")
    return articles

def get_good_class_articles():
    site = mwclient.Site('en.wikipedia.org', clients_useragent='clip_embedding_wikipedia/0.0 (https://calebkruse.com/; caleb.krs@gmail.com)')
    articles = []
    counter = 0
    for category in site.categories['GA-Class_articles'].members():
        if category.length > 0:
            for member in category.members():
                try:
                    title = member.name.split(':')[1]
                    articles.append(title)
                    counter += 1
                    if counter % 500 == 0:
                        print(f"Grabbed {counter} good article titles")
                except Exception as e:
                    print(f"Error processing {member.name}: {e}")
    return articles

# %%
good_articles = get_good_class_articles()
# Out:
# Grabbed 500 good article titles
# Grabbed 1000 good article titles
# Grabbed 1500 good article titles
# Grabbed 2000 good article titles
# Grabbed 2500 good article titles
# Grabbed 3000 good article titles
# Grabbed 3500 good article titles
# Grabbed 4000 good article titles
# Grabbed 4500 good article titles
# Grabbed 5000 good article titles
# Grabbed 5500 good article titles
# Grabbed 6000 good article titles
# Grabbed 6500 good article titles
# Grabbed 7000 good article titles
# Grabbed 7500 good article titles
# Grabbed 8000 good article titles
# Grabbed 8500 good article titles
# Grabbed 9000 good article titles
# Grabbed 9500 good article titles
# Grabbed 10000 good article titles
# Grabbed 10500 good article titles
# Grabbed 11000 good article titles
# Grabbed 11500 good article titles
# Grabbed 12000 good article titles
# Grabbed 12500 good article titles
# Grabbed 13000 good article titles
# Grabbed 13500 good article titles
# Grabbed 14000 good article titles
# Grabbed 14500 good article titles
# Grabbed 15000 good article titles
# Grabbed 15500 good article titles
# Grabbed 16000 good article titles
# Grabbed 16500 good article titles
# Grabbed 17000 good article titles
# Grabbed 17500 good article titles
# Grabbed 18000 good article titles
# Grabbed 18500 good article titles
# Grabbed 19000 good article titles
# Grabbed 19500 good article titles
# Grabbed 20000 good article titles
# Grabbed 20500 good article titles
# Grabbed 21000 good article titles
# Grabbed 21500 good article titles
# Grabbed 22000 good article titles
# Grabbed 22500 good article titles
# Grabbed 23000 good article titles
# Grabbed 23500 good article titles
# Grabbed 24000 good article titles
# Grabbed 24500 good article titles
# Grabbed 25000 good article titles
# Grabbed 25500 good article titles
# Grabbed 26000 good article titles
# Grabbed 26500 good article titles
# Grabbed 27000 good article titles
# Grabbed 27500 good article titles
# Grabbed 28000 good article titles
# Grabbed 28500 good article titles
# Grabbed 29000 good article titles
# Grabbed 29500 good article titles
# Grabbed 30000 good article titles
# Grabbed 182000 good article titles
# Grabbed 182500 good article titles
# Grabbed 183000 good article titles
# Grabbed 183500 good article titles
# Grabbed 184000 good article titles
# Grabbed 184500 good article titles
# Grabbed 185000 good article titles
# Grabbed 185500 good article titles
# Grabbed 186000 good article titles
# Grabbed 186500 good article titles
# Grabbed 187000 good article titles
# Grabbed 187500 good article titles
# Grabbed 188000 good article titles
# Grabbed 188500 good article titles
# Grabbed 189000 good article titles
# Grabbed 189500 good article titles
# Grabbed 190000 good article titles
# Grabbed 190500 good article titles
# Grabbed 191000 good article titles
# Grabbed 191500 good article titles
# Grabbed 192000 good article titles
# Grabbed 192500 good article titles
# Grabbed 193000 good article titles

# %%
orchestrator = WikiEmbeddingsOrchestrator()

# For vital articles
#orchestrator.generate_embeddings(source=ArticleSource.VITAL, vital_level=2)

# For good articles
#orchestrator.generate_embeddings(source=ArticleSource.GOOD)

# For A-Class articles
#orchestrator.generate_embeddings(source=ArticleSource.A_CLASS)

# For custom article list

#titles = ["Python (programming language)", "Machine learning", "Artificial intelligence"]
orchestrator.generate_embeddings(source=ArticleSource.CUSTOM, custom_titles=good_articles)
# Out:
# 2025-02-02 10:36:05,719 - WARNING - Connection error. Retrying in a moment.
# 2025-02-02 10:36:32,913 - INFO - Found 191243 articles to process
# 2025-02-02 10:36:33,645 - INFO - Processed 32/191243 articles
# 2025-02-02 10:36:33,993 - INFO - Processed 64/191243 articles
# 2025-02-02 10:36:34,487 - INFO - Processed 96/191243 articles
# 2025-02-02 10:36:34,955 - INFO - Processed 128/191243 articles
# 2025-02-02 10:36:35,464 - INFO - Processed 160/191243 articles
# 2025-02-02 10:36:35,944 - INFO - Processed 192/191243 articles
# 2025-02-02 10:36:37,325 - INFO - Processed 224/191243 articles
# 2025-02-02 10:36:37,735 - INFO - Processed 256/191243 articles
# 2025-02-02 10:36:38,143 - INFO - Processed 288/191243 articles
# 2025-02-02 10:36:38,534 - INFO - Processed 320/191243 articles
# 2025-02-02 10:36:38,967 - INFO - Processed 352/191243 articles
# 2025-02-02 10:36:39,363 - INFO - Processed 384/191243 articles
# 2025-02-02 10:36:39,781 - INFO - Processed 416/191243 articles
# 2025-02-02 10:36:40,221 - INFO - Processed 448/191243 articles
# 2025-02-02 10:36:40,706 - INFO - Processed 480/191243 articles
# 2025-02-02 10:36:41,113 - INFO - Processed 512/191243 articles
# 2025-02-02 10:36:41,500 - INFO - Processed 544/191243 articles
# 2025-02-02 10:36:41,907 - INFO - Processed 576/191243 articles
# 2025-02-02 10:36:42,285 - INFO - Processed 608/191243 articles
# 2025-02-02 10:36:42,710 - INFO - Processed 640/191243 articles
# 2025-02-02 10:36:43,101 - INFO - Processed 672/191243 articles
# 2025-02-02 10:36:43,420 - INFO - Processed 704/191243 articles
# 2025-02-02 10:36:43,840 - INFO - Processed 736/191243 articles
# 2025-02-02 10:36:44,189 - INFO - Processed 768/191243 articles
# 2025-02-02 10:36:45,030 - INFO - Processed 800/191243 articles
# 2025-02-02 10:36:45,388 - INFO - Processed 832/191243 articles
# 2025-02-02 11:15:38,849 - INFO - Processed 190208/191243 articles
# 2025-02-02 11:15:39,117 - INFO - Processed 190240/191243 articles
# 2025-02-02 11:15:39,430 - INFO - Processed 190272/191243 articles
# 2025-02-02 11:15:39,713 - INFO - Processed 190304/191243 articles
# 2025-02-02 11:15:40,037 - INFO - Processed 190336/191243 articles
# 2025-02-02 11:15:40,332 - INFO - Processed 190368/191243 articles
# 2025-02-02 11:15:40,669 - INFO - Processed 190400/191243 articles
# 2025-02-02 11:15:40,978 - INFO - Processed 190432/191243 articles
# 2025-02-02 11:15:41,297 - INFO - Processed 190464/191243 articles
# 2025-02-02 11:15:41,612 - INFO - Processed 190496/191243 articles
# 2025-02-02 11:15:41,916 - INFO - Processed 190528/191243 articles
# 2025-02-02 11:15:42,216 - INFO - Processed 190560/191243 articles
# 2025-02-02 11:15:42,539 - INFO - Processed 190592/191243 articles
# 2025-02-02 11:15:42,836 - INFO - Processed 190624/191243 articles
# 2025-02-02 11:15:43,196 - INFO - Processed 190656/191243 articles
# 2025-02-02 11:15:43,534 - INFO - Processed 190688/191243 articles
# 2025-02-02 11:15:43,869 - INFO - Processed 190720/191243 articles
# 2025-02-02 11:15:44,199 - INFO - Processed 190752/191243 articles
# 2025-02-02 11:15:44,512 - INFO - Processed 190784/191243 articles
# 2025-02-02 11:15:44,878 - INFO - Processed 190816/191243 articles
# 2025-02-02 11:15:45,189 - INFO - Processed 190848/191243 articles
# 2025-02-02 11:15:45,507 - INFO - Processed 190880/191243 articles
# 2025-02-02 11:15:45,849 - INFO - Processed 190912/191243 articles
# 2025-02-02 11:15:46,181 - INFO - Processed 190944/191243 articles
# 2025-02-02 11:15:46,547 - INFO - Processed 190976/191243 articles
# 2025-02-02 11:15:46,869 - INFO - Processed 191008/191243 articles
# 2025-02-02 11:15:47,182 - INFO - Processed 191040/191243 articles
# 2025-02-02 11:15:47,590 - INFO - Processed 191072/191243 articles
# 2025-02-02 11:15:47,871 - INFO - Processed 191104/191243 articles
# 2025-02-02 11:15:48,306 - INFO - Processed 191136/191243 articles
# 2025-02-02 11:15:48,627 - INFO - Processed 191168/191243 articles
# 2025-02-02 11:15:48,953 - INFO - Processed 191200/191243 articles
# 2025-02-02 11:15:49,262 - INFO - Processed 191232/191243 articles
# 2025-02-02 11:15:49,771 - INFO - Processed 191243/191243 articles

# %%
# Basic initialization
orchestrator = WikiEmbeddingsOrchestrator(
    model_name="openai/clip-vit-base-patch32",
    db_path="wiki_embeddings.db",
    batch_size=128
)

# Generate embeddings for vital articles (level 4)
orchestrator.generate_embeddings(vital_level=2)
# Out:
# 2025-02-02 09:02:05,829 - INFO - Found 101 articles to process
# 2025-02-02 09:02:06,926 - INFO - Processed 101/101 articles

# %%
articles = set()

for year in range(2016, 2024):
    print(year)
    # get all the months with 31 days
    for month in [1,3,5,7,8,10,12]:
        top_articles = get_top_articles(1000, month, year)
        articles.update(top_articles['article'].tolist())
articles = list(articles)

# %%
generator = WikiEmbeddingsGenerator()
generator.generate_embeddings(articles=articles)

# %%
# Read and search
reader = WikiEmbeddingsReader()
similar = reader.get_similar_articles("computer mouse")
for article in similar:
    print(f"{article['title']}: {article['similarity']:.3f}")

# %%
# Initialize the reader
reader = ImageEmbeddingsReader()
image_url = "/Users/clkruse/Downloads/ginger_test.png"
# Find similar articles for an image
similar_articles = reader.get_similar_articles_by_image(image_url, limit=5)
similar_articles

# %%
import mwviews.api
import pandas as pd

def get_top_articles(limit=100, month=12, year=2024):
    # Initialize the PageviewsClient
    user_agent = 'clip_embedding_wikipedia/0.0 (https://calebkruse.com/; caleb.krs@gmail.com)'
    client = mwviews.api.PageviewsClient(user_agent=user_agent)
    
    # Get daily views for all articles
    views = client.top_articles('en.wikipedia', limit=limit, month=month,year=year)
    
    return pd.DataFrame(views)

# %%
articles = set()

for year in range(2016, 2024):
    print(year)
    # get all the months with 31 days
    for month in [1,3,5,7,8,10,12]:
        top_articles = get_top_articles(1000, month, year)
        articles.update(top_articles['article'].tolist())
articles = list(articles)
articles[:10]

# %%
#get embeddings for all the articles
embedder = WikiEmbeddingsGenerator()
embedder.generate_embeddings(articles=articles)

# %% [markdown]
# # New version

# %%
site = mwclient.Site('en.wikipedia.org', clients_useragent='clip_embedding_wikipedia/0.0 (https://calebkruse.com/; caleb.krs@gmail.com)')

good_article_base = 'Category:Articles by quality'
# start by getting all categories
categories = []
page = site.pages[good_article_base]
for line in page.text().split('\n'):
        print(line)
# Out:
# {{Wikipedia category}}
# Articles assessed as part of the [[Wikipedia:Version 1.0 Editorial Team|Version 1.0 Editorial Team]]'s [[WP:WVWP|Work via WikiProjects]] scheme.
# A list of participating projects along with their statistics can be found in the [[Wikipedia:Version 1.0 Editorial Team/Index of subjects|Index of subjects]]. Article assessments by WikiProject can be found in [[:Category:Wikipedia 1.0 assessments]].
# <!-- <categorytree>Articles by quality</categorytree> -->
# {{CatAutoTOC}}
#
# [[Category:Wikipedia 1.0 assessments|*]]

# %%
articles = []
counter = 0
for category in site.categories['A-Class_articles'].members():
    #print(category.name)
    if category.length > 0:
        for member in category.members():
            title = member.name.split(':')[1]
            articles.append(title)
            counter += 1
            if counter % 500 == 0:
                print(f"Grabbed {counter} A-Class article titles")
# Out:
# Grabbed 500 A-Class article titles
# Grabbed 1000 A-Class article titles
# Grabbed 1500 A-Class article titles
# Grabbed 2000 A-Class article titles
# Grabbed 2500 A-Class article titles
# Grabbed 3000 A-Class article titles
# Grabbed 3500 A-Class article titles
# Grabbed 4000 A-Class article titles
# Grabbed 4500 A-Class article titles
# Grabbed 5000 A-Class article titles
# Grabbed 5500 A-Class article titles

# %%
articles
# Out:
# ['Ontario Highway 55',
#  'Ontario Highway 404',
#  'Ontario Highway 405',
#  'Ontario Highway 427',
#  'D21 road (Croatia)',
#  'Ontario Highway 55',
#  'Ontario Highway 404',
#  'Ontario Highway 405',
#  'Ontario Highway 427',
#  'Annika Sörenstam',
#  'Bessas (magister militum)',
#  'Minden Blake',
#  'Oswald Boelcke',
#  'Alan Charlesworth',
#  'Wilfred Clouston',
#  'Hippolyte De La Rue',
#  'Alan Deere',
#  'Mato Dukovac',
#  'Rudolf Frank',
#  'Yuri Gagarin',
#  'Gordon Gollob',
#  'Hermann Graf',
#  'Erich Hartmann',
#  'Michael Herrick',
#  'George Kenney',
#  'Albert Kesselring',
#  'Ernest J. King',
#  'Egmont Prinz zur Lippe-Weißenfeld',
#  'Frank Lukis',
#  'Günther Lützow',
#  'George Mackinolty',
#  'Hans-Joachim Marseille',
#  'Egon Mayer',
#  'William McAloney',
#  'Walter Nowotny',
#  'Max-Hellmuth Ostermann',
#  'Keith Park',
#  'Heinrich Prinz zu Sayn-Wittgenstein',
#  'Heinz-Wolfgang Schnaufer',
#  'Elliot See',
#  'Leonard Trent',
#  'Werner Voss',
#  'Hans Waldmann (fighter pilot)',
#  'James Allen Ward',
#  'Theodor Weissenberger',
#  'Ennis Whitehead',
#  'Wolf-Dietrich Wilcke',
#  'Donald Wilson (general)',
#  'List of World War I aces credited with 5 victories',
#  'Josef Wurmheller',
#  'Paul Wurtsmith',
#  'Asad ibn Abdallah al-Qasri',
#  'Camp Chapman attack',
#  '2008 invasion of Anjouan',
#  'Battle of Berea',
#  'Cyclone Leon–Eline',
#  'Napoleon',
#  'A-Class Algeria articles',
#  'A-Class Western Sahara articles',
#  'Kirk–Holden war',
#  'Red Tail Squadron',
#  'A-Class African diaspora visual arts articles',
#  '7 Independent Company (Rhodesia)',
#  '2008 invasion of Anjouan',
#  'Ahmad ibn Tulun',
#  'Armed Forces of Liberia',
#  'Australian contribution to UNTAG',
#  'Auxilia',
#  'Battle of Berea',
#  'Battle of Elands River (1900)',
#  'Battle of Entebbe',
#  'Battle of Lukaya',
#  'Battle of Magersfontein',
#  'Battle of Masaka',
#  'Battle of the Blacks',
#  'Battle of Utica',
#  'Egyptian–Libyan War',
#  'Fatimid invasion of Egypt (914–915)',
#  'Gisco (died 239 BC)',
#  'Invasion of Kagera',
#  'Philippe Leclerc de Hauteclocque',
#  'Jean-Baptiste Ouédraogo',
#  'Siege of Kimberley',
#  'Siege of Tunis (Mercenary War)',
#  'Southern Rhodesian military involvement in the Malayan Emergency',
#  'John Troglita',
#  'Arado E.381',
#  'Boeing B-52 Stratofortress',
#  'Hall XPTBH',
#  'Lockheed YF-22',
#  'McDonnell Douglas Phantom in UK service',
#  'Mikoyan-Gurevich MiG-3',
#  'Patrie (airship)',
#  'Petlyakov Pe-3',
#  'Petlyakov Pe-8',
#  'Republic F-84 Thunderjet',
#  'Sukhoi Su-25',
#  'Sukhoi Su-37',
#  'Yermolayev Yer-2',
#  'CFM International CFM56',
#  'Grunge',
#  '3rd Missouri Infantry Regiment (Confederate)',
#  '9th Missouri Sharpshooter Battalion',
#  '29th Massachusetts Infantry Regiment',
#  'Barton S. Alexander',
#  'Army of the Tennessee',
#  'Battle of Fort Donelson',
#  'Battle of Fort Henry',
#  'Battle of Gettysburg, first day',
#  'Battle of Gettysburg, second day',
#  'CSS Missouri',
#  'Fort Bayard (Washington, D.C.)',
#  'Fort Jackson (Virginia)',
#  'Fort Runyon',
#  'Fort Stanton (Washington, D.C.)',
#  'Benjamin Lewis Hodge',
#  'Massachusetts in the American Civil War',
#  'Benjamin Franklin Tilley',
#  'United States Zouave Cadets',
#  'Grunge',
#  'Battle of Fort Washington',
#  'HMS Endeavour',
#  'Powder Alarm',
#  'Casimir Pulaski',
#  'Siege of Fort Ticonderoga (1777)',
#  'William Stacy',
#  'Battle of Artemisium',
#  'A-Class Andaman and Nicobar Islands articles of High-importance',
#  'A-Class Andaman and Nicobar Islands articles of Low-importance',
#  'A-Class Andaman and Nicobar Islands articles of Mid-importance',
#  'A-Class Andaman and Nicobar Islands articles of Top-importance',
#  'A-Class Andaman and Nicobar Islands articles of Unknown-importance',
#  'A-Class Andhra Pradesh articles of High-importance',
#  'A-Class Andhra Pradesh articles of Low-importance',
#  'A-Class Andhra Pradesh articles of Mid-importance',
#  'A-Class Andhra Pradesh articles of Top-importance',
#  'A-Class Andhra Pradesh articles of Unknown-importance',
#  'Napoleon',
#  'A-Class Animation articles by work groups',
#  'Frank Worsley',
#  'Abbasid invasion of Asia Minor (782)',
#  'Arab–Byzantine wars',
#  'Asad ibn Abdallah al-Qasri',
#  'Battle of Andrassos',
#  'North Yemen civil war',
#  'A-Class Algeria articles',
#  'A-Class Western Sahara articles',
#  'Wheel',
#  'Bastille',
#  'A-Class Argentine Antarctica articles',
#  "Abu'l-Aswar Shavur ibn Fadl",
#  'Ashot Nadanian',
#  'Roman–Parthian War of 58–63',
#  'Samba',
#  'A-Class Kylie Minogue articles',
#  'A-Class Alternative music articles',
#  'A-Class Apple Corps and Apple Records articles',
#  'A-Class biography (arts and entertainment) articles',
#  'A-Class Britney Spears articles',
#  'A-Class Christina Aguilera articles',
#  'A-Class electronic music articles',
#  'A-Class Brian Epstein articles',
#  'A-Class film articles',
#  'A-Class Firefly articles',
#  'A-Class Gilbert and Sullivan articles',
#  'A-Class George Harrison articles',
#  'A-Class Hip-hop articles',
#  'A-Class horror articles',
#  'A-Class John Lennon articles',
#  'A-Class Lost articles',
#  'A-Class George Martin articles',
#  'A-Class Paul McCartney articles',
#  'A-Class Narnia articles',
#  'A-Class novel articles',
#  'A-Class Prison Break articles',
#  'A-Class Record Charts articles',
#  'A-Class romance articles',
#  'A-Class Ringo Starr articles',
#  'A-Class television articles',
#  'A-Class United States Government articles',
#  'A-Class Arunachal Pradesh articles of High-importance',
#  'A-Class Arunachal Pradesh articles of Low-importance',
#  'A-Class Arunachal Pradesh articles of Mid-importance',
#  'A-Class Arunachal Pradesh articles of Top-importance',
#  'A-Class Arunachal Pradesh articles of Unknown-importance',
#  'Battle of Khe Sanh',
#  'Sam Manekshaw',
#  'Param Vir Chakra',
#  'Siege of Arrah',
#  '1st Filipino Infantry Regiment',
#  '3rd Bengal Light Cavalry',
#  '1965 South Vietnamese coup',
#  '1975 spring offensive',
#  'Arab–Khazar wars',
#  'Atomic bombings of Hiroshima and Nagasaki',
#  'Battle of Battle Mountain',
#  'Battle of Chochiwon',
#  'Battle of Chonan',
#  'Battle of Haman',
#  'Battle of Hulao',
#  'Battle of Hwanggan',
#  'Battle of Isurava',
#  'Battle of Kapyong',
#  'Battle of Kharistan',
#  'Battle of Khe Sanh',
#  'Battle of Masan',
#  'Battle of Nam River',
#  "Battle of P'ohang-dong",
#  'Battle of Porton Plantation',
#  'Battle of Pusan Perimeter logistics',
#  'Battle of Pyongtaek',
#  'Battle of Sangju (1950)',
#  "Battle of Slater's Knoll",
#  'Battle of Taegu',
#  'Battle of the Bowling Alley',
#  'Battle of the Hongorai River',
#  'Battle of the Pusan Perimeter',
#  'Battle of Tsimba Ridge',
#  'Battle of Wau',
#  'Battle of Yongdong',
#  'Jon Burge',
#  'Cambodian campaign',
#  'Cambodian Civil War',
#  'Camp Chapman attack',
#  'Cho Ki-chon',
#  'Citadel of Saigon',
#  'Coast Guard Squadron One',
#  'William F. Dean',
#  'Trương Định',
#  'Easter Offensive',
#  'First Battle of Maryang-san',
#  'First Battle of Naktong Bulge',
#  'Hadong Ambush',
#  'I Corps (United States)',
#  'Indonesian occupation of East Timor',
#  'January 1964 South Vietnamese coup',
#  'Japanese air attacks on the Mariana Islands',
#  'Japanese aircraft carrier Zuihō',
#  'Japanese battleship Hatsuse',
#  'Japanese battleship Hiei',
#  'Japanese battleship Kawachi',
#  'Japanese battleship Kirishima',
#  'Japanese battleship Kongō',
#  'Japanese battleship Musashi',
#  'Japanese battleship Mutsu',
#  'Japanese cruiser Ibuki (1943)',
#  'Java War (1741–1743)',
#  'Kongō-class battlecruiser',
#  'Lâm Văn Phát',
#  'Landing on Emirau',
#  'Landings at Cape Torokina',
#  'Lê Văn Duyệt',
#  'Philippe Leclerc de Hauteclocque',
#  'Sam Manekshaw',
#  'Moro River campaign',
#  'New Britain campaign',
#  'Gia Long',
#  'Nguyễn Văn Nhung',
#  'Operation Coburg',
#  'Operation Cockpit',
#  'Operation Crimp',
#  'Operation Igloo White',
#  'Operation Lam Son 719',
#  'Operation Rolling Thunder',
#  'Param Vir Chakra',
#  'Sasaki Tōichi',
#  'Siege of Arrah',
#  'Southern Rhodesian military involvement in the Malayan Emergency',
#  'Tet Offensive',
#  'United Nations Command–Rear',
#  'Yên Bái mutiny',
#  'A-Class Assam articles of High-importance',
#  'A-Class Assam articles of Low-importance',
#  'A-Class Assam articles of Mid-importance',
#  'A-Class Assam articles of Top-importance',
#  'A-Class Assam articles of Unknown-importance',
#  '2/2nd Machine Gun Battalion (Australia)',
#  '2/3rd Battalion (Australia)',
#  '2/3rd Machine Gun Battalion (Australia)',
#  '2/4th Machine Gun Battalion (Australia)',
#  '2/5th Battalion (Australia)',
#  '2/7th Battalion (Australia)',
#  '2/9th Battalion (Australia)',
#  '2/10th Battalion (Australia)',
#  '2/14th Battalion (Australia)',
#  '2/15th Battalion (Australia)',
#  '2/17th Battalion (Australia)',
#  '2/18th Battalion (Australia)',
#  '2/43rd Battalion (Australia)',
#  '2/48th Battalion (Australia)',
#  '4th Armoured Brigade (Australia)',
#  '12th Light Horse Regiment (Australia)',
#  '15th Battalion (Australia)',
#  'Air Combat Group RAAF',
#  'Australian Army during World War II',
#  'Australian contribution to UNTAG',
#  'Australian light destroyer project',
#  'Battle of Bita Paka',
#  'Battle of Isurava',
#  'Battle of Kapyong',
#  'Battle of Porton Plantation',
#  "Battle of Slater's Knoll",
#  'Battle of the Hongorai River',
#  'Battle of Tsimba Ridge',
#  'Battle of Wau',
#  'Philip Baxter',
#  'Roy Burston',
#  'James Cannan',
#  'Alan Charlesworth',
#  'Percy Cherry',
#  'Thomas Cooke (soldier, born 1881)',
#  'Cyclone Leon–Eline',
#  'Hippolyte De La Rue',
#  'First Battle of Maryang-san',
#  'Stanley Gibbs',
#  'Great Northern Highway',
#  'John Hines (Australian soldier)',
#  'George Howell (soldier)',
#  'Tim Hughes (soldier)',
#  'George Ingram',
#  'Clarence Jeffries',
#  'Landing at Jacquinot Bay',
#  'Landing at Saidor',
#  'Frank Lukis',
#  'George Mackinolty',
#  'Joseph Maxwell',
#  'William McAloney',
#  'Lewis McGee (soldier)',
#  'New Britain campaign',
#  'No. 78 Wing RAAF',
#  'No. 84 Wing RAAF',
#  'John Northcott',
#  'Operation Coburg',
#  'Operation Crimp',
#  'Operation Totem',
#  'Ordnance QF 25-pounder Short',
#  'Horace Robertson',
#  'Sydney Rowell',
#  'Teddy Sheean',
#  'Colin Hall Simpson',
#  'South Australian Mounted Rifles',
#  'Percy Statton',
#  'Percy Storkey',
#  'Ernest Titterton',
#  'Tonkin Highway',
#  'George Alan Vasey',
#  'A-Class Banksia articles',
#  'A-Class Australian baseball articles',
#  'A-Class Australian basketball articles',
#  'A-Class Australian biota articles',
#  'A-Class Australian crime articles',
#  'A-Class Demographics of Australia articles',
#  'A-Class Australian exploration articles',
#  'A-Class Australian history articles',
#  'A-Class Indigenous peoples of Australia articles',
#  'A-Class Australian law articles',
#  'A-Class Australian maritime history articles',
#  'A-Class Melbourne articles',
#  'A-Class Australian music articles',
#  'A-Class New South Wales articles',
#  'A-Class Northern Territory articles',
#  'A-Class Australian places articles',
#  'A-Class Australian politics articles',
#  'A-Class Queensland articles',
#  'A-Class Australia road transport articles',
#  'A-Class South Australia articles',
#  'A-Class Australian sports articles',
#  'A-Class Tasmania articles',
#  'A-Class Australian television articles',
#  'A-Class Australian Transport articles',
#  'A-Class Western Australia articles',
#  'Great Northern Highway',
#  'Mitchell Freeway',
#  'Tonkin Highway',
#  '1st Armoured Brigade (Australia)',
#  '2/1st Machine Gun Battalion (Australia)',
#  '2/2nd Machine Gun Battalion (Australia)',
#  '2/3rd Battalion (Australia)',
#  '2/3rd Machine Gun Battalion (Australia)',
#  '2/4th Machine Gun Battalion (Australia)',
#  '2/5th Battalion (Australia)',
#  '2/7th Battalion (Australia)',
#  '2/9th Battalion (Australia)',
#  '2/10th Battalion (Australia)',
#  '2/14th Battalion (Australia)',
#  '2/15th Battalion (Australia)',
#  '2/17th Battalion (Australia)',
#  '2/18th Battalion (Australia)',
#  '2/43rd Battalion (Australia)',
#  '2/48th Battalion (Australia)',
#  '4th Armoured Brigade (Australia)',
#  '10th Battalion (Australia)',
#  '12th Light Horse Regiment (Australia)',
#  '15th Battalion (Australia)',
#  '18th Battalion (New Zealand)',
#  '20th Battalion (New Zealand)',
#  '25th Battalion (New Zealand)',
#  'Air Combat Group RAAF',
#  'Leslie Andrew',
#  'Australian Army during World War II',
#  'Australian contribution to UNTAG',
#  'Australian light destroyer project',
#  'Battle of Bita Paka',
#  'Battle of Elands River (1900)',
#  'Battle of Isurava',
#  'Battle of Kapyong',
#  'Battle of Messines (1917)',
#  'Battle of Porton Plantation',
#  'Battle of Puketutu',
#  "Battle of Slater's Knoll",
#  'Battle of the Hongorai River',
#  'Battle of Tsimba Ridge',
#  'Battle of Wau',
#  'Philip Baxter',
#  'Minden Blake',
#  'Roy Burston',
#  'James Cannan',
#  'Central Flying School RAAF',
#  'Alan Charlesworth',
#  'Johnny Checketts',
#  'Percy Cherry',
#  'Wilfred Clouston',
#  'Collins-class submarine',
#  'Thomas Cooke (soldier, born 1881)',
#  'James Crichton (soldier)',
#  'Wilbur Dartnell',
#  'Hippolyte De La Rue',
#  'Alan Deere',
#  'First Battle of Maryang-san',
#  'Samuel Forsyth',
#  'Samuel Frickleton',
#  'Stanley Gibbs',
#  'Alexander Godley',
#  'John Gildroy Grant',
#  'Herbert Hart (general)',
#  'Lindsay Hassett',
#  'Norman Frederick Hastings',
#  'Michael Herrick',
#  'John Hines (Australian soldier)',
#  'HMAS Sydney (R17)',
#  'George Howell (soldier)',
#  'Tim Hughes (soldier)',
#  'Clive Hulme',
#  'George Ingram',
#  'Clarence Jeffries',
#  'Reginald Judson',
#  'George Kenney',
#  'Howard Kippenberger',
#  'Landing at Jacquinot Bay',
#  'Landing at Saidor',
#  'Harry Laurent',
#  'Frank Lukis',
#  'George Mackinolty',
#  'William George Malone',
#  'Joseph Maxwell',
#  'William McAloney',
#  'Lewis McGee (soldier)',
#  'Keith Miller',
#  'Moro River campaign',
#  'Leslie Morshead',
#  'New Britain campaign',
#  'New Zealand Division',
#  'Henry James Nicholas',
#  'No. 78 Wing RAAF',
#  'No. 81 Wing RAAF',
#  'No. 82 Wing RAAF',
#  'No. 84 Wing RAAF',
#  'No. 86 Wing RAAF',
#  'John Northcott',
#  'Operation Coburg',
#  'Operation Cockpit',
#  'Operation Crimp',
#  'Operation Mosaic',
#  'Operation Totem',
#  'Ordnance QF 25-pounder Short',
#  'Keith Park',
#  'Jack Rae',
#  'Horace Robertson',
#  'Sydney Rowell',
#  'Teddy Sheean',
#  'Siege of Ngatapa',
#  'Colin Hall Simpson',
#  'South Australian Mounted Rifles',
#  'South West Pacific Area',
#  'Percy Statton',
#  'Percy Storkey',
#  'Tet Offensive',
#  'Ernest Titterton',
#  'Leonard Trent',
#  'George Alan Vasey',
#  'Frank Worsley',
#  'A-Class Australian Antarctic Territory articles',
#  'A-Class Canberra articles',
#  'A-Class Victoria articles',
#  'A-Class Australian motorsport articles',
#  'A-Class Australian rules football articles',
#  'Great Northern Highway',
#  'Tonkin Highway',
#  'Battle of Emmendingen',
#  'Battle of Marengo',
#  'Ersatz Monarch-class battleship',
#  'Gordon Gollob',
#  'Egmont Prinz zur Lippe-Weißenfeld',
#  'Walter Nowotny',
#  'Johann Heinrich von Schmitt',
#  'Siege of Kehl (1796–1797)',
#  'SM U-5 (Austria-Hungary)',
#  'U-3-class submarine',
#  'U-5-class submarine',
#  'U-20-class submarine',
#  '11th Airborne Division',
#  '1994 Fairchild Air Force Base B-52 crash',
#  'Air Combat Group RAAF',
#  'Arado E.381',
#  'Minden Blake',
#  'Boeing B-52 Stratofortress',
#  'Oswald Boelcke',
#  'CFM International CFM56',
#  'Alan Charlesworth',
#  'Wilfred Clouston',
#  'Hippolyte De La Rue',
#  'De Lackner HZ-1 Aerocycle',
#  'Alan Deere',
#  'Mato Dukovac',
#  'Rudolf Frank',
#  'Yuri Gagarin',
#  'Gordon Gollob',
#  'Hermann Graf',
#  'H2S (radar)',
#  'Hall XPTBH',
#  'Erich Hartmann',
#  'Michael Herrick',
#  'Ikarus IK-2',
#  'George Kenney',
#  'Albert Kesselring',
#  'Ernest J. King',
#  'Egmont Prinz zur Lippe-Weißenfeld',
#  'Lockheed AH-56 Cheyenne',
#  'Lockheed YF-22',
#  'Frank Lukis',
#  'Günther Lützow',
#  'George Mackinolty',
#  'Hans-Joachim Marseille',
#  'Egon Mayer',
#  'William McAloney',
#  'McDonnell Douglas Phantom in UK service',
#  'Mikoyan-Gurevich MiG-3',
#  'No. 78 Wing RAAF',
#  'Walter Nowotny',
#  'Max-Hellmuth Ostermann',
#  'Keith Park',
#  'Patrie (airship)',
#  'Petlyakov Pe-3',
#  'Petlyakov Pe-8',
#  'Red Tail Squadron',
#  'Republic F-84 Thunderjet',
#  'Heinrich Prinz zu Sayn-Wittgenstein',
#  'Heinz-Wolfgang Schnaufer',
#  'Elliot See',
#  'Sukhoi Su-25',
#  'Sukhoi Su-37',
#  'Leonard Trent',
#  'Werner Voss',
#  'Hans Waldmann (fighter pilot)',
#  'James Allen Ward',
#  'Theodor Weissenberger',
#  'Ennis Whitehead',
#  'Wolf-Dietrich Wilcke',
#  'Donald Wilson (general)',
#  'List of World War I aces credited with 5 victories',
#  'Josef Wurmheller',
#  'Paul Wurtsmith',
#  'Yermolayev Yer-2',
#  '1994 Fairchild Air Force Base B-52 crash',
#  "Abu'l-Aswar Shavur ibn Fadl",
#  '1st Army Group (Kingdom of Yugoslavia)',
#  '19th Mechanized Division (Greece)',
#  '32nd Infantry Division Triglavski',
#  '38th Infantry Division Dravska',
#  '40th Infantry Division Slavonska',
#  '42nd Infantry Division Murska',
#  '373rd (Croatian) Infantry Division',
#  'Arab–Byzantine wars',
#  'Alexandru Averescu',
#  'Ba Congress',
#  'Battle of Cer',
#  'Battle of Gallipoli (1416)',
#  'Battle of Sarantaporo',
#  'Battle of Vaslui',
#  'Bijeljina massacre',
#  'Tim Cross',
#  'Milorad Ekmečić',
#  'Ersatz Monarch-class battleship',
#  'First Battle of Târgu Frumos',
#  'Ikarus IK-2',
#  "Jastrebarsko children's camp",
#  'Kidnapping of Heinrich Kreipe',
#  'Vojislav Lukačević',
#  'Yannis Makriyannis',
#  'Minefields in Croatia',
#  'Navy of the Independent State of Croatia',
#  'Operation Deny Flight',
#  'Operation Jackal',
#  'Operation Sky Monitor',
#  'Operation Southeast Croatia',
#  'Operation Storm',
#  'Operation Trio',
#  "Operation Winter '94",
#  'Orjen-class torpedo boat',
#  'Zaharije Ostojić',
#  'Osvetnik-class submarine',
#  'Ottoman conquest of Lesbos',
#  'Pećanac Chetniks',
#  'Priscus (magister militum)',
#  'Helmuth Raithel',
#  'Royal Yugoslav Navy',
#  'Sd.Kfz. 10',
#  'Serbian State Guard',
#  "Skanderbeg's Italian expedition",
#  'SM UB-45',
#  "Sviatoslav's invasion of Bulgaria",
#  'Tito–Stalin split',
#  'United Nations Confidence Restoration Operation in Croatia',
#  'Vitalian (consul)',
#  'Wallachian Revolution of 1848',
#  "Yugoslav coup d'état",
#  'Yugoslav submarine Osvetnik',
#  'Yugoslav submarine Smeli',
#  'Yugoslav torpedo boat T8',
#  'Kaunas Fortress',
#  'Livonian War',
#  'Smolensk War',
#  '3rd Bengal Light Cavalry',
#  'Jacob L. Devers',
#  'A-Class Baseball articles by project',
#  "Thirty Years' War",
#  'Battle of the Kalka River',
#  'Mato Dukovac',
#  'Vojislav Lukačević',
#  'Siege of Arrah',
#  'A-Class Bihar articles of High-importance',
#  'A-Class Bihar articles of Low-importance',
#  'A-Class Bihar articles of Mid-importance',
#  'A-Class Bihar articles of Top-importance',
#  'A-Class Bihar articles of Unknown-importance',
#  'Rudolf Abel',
#  "Abu'l-Aswar Shavur ibn Fadl",
#  'Barton S. Alexander',
#  'Leslie Andrew',
#  'Hubert Aquin',
#  'Asad ibn Abdallah al-Qasri',
#  'Alexandru Averescu',
#  'Philip Baxter',
#  'Bessas (magister militum)',
#  'Minden Blake',
#  'Bleeding Through',
#  'Oswald Boelcke',
#  'Frank Buckles',
#  'Roy Burston',
#  'James Cannan',
#  'Hugh John Casey',
#  'Alan Charlesworth',
#  'Johnny Checketts',
#  'Percy Cherry',
#  'Cho Ki-chon',
#  'Wilfred Clouston',
#  'Thomas Cooke (soldier, born 1881)',
#  'James Crichton (soldier)',
#  'Michael J. Daly',
#  'Hippolyte De La Rue',
#  'Alan Deere',
#  'Jacob L. Devers',
#  'Trương Định',
#  'Mato Dukovac',
#  'Robert L. Eichelberger',
#  'Milorad Ekmečić',
#  'Hermann Fegelein',
#  'Samuel Forsyth',
#  'Rudolf Frank',
#  'Samuel Frickleton',
#  'Yuri Gagarin',
#  'Germanicus',
#  'Stanley Gibbs',
#  'Alexander Godley',
#  'Gordon Gollob',
#  'Gordian dynasty',
#  'Hermann Graf',
#  'John Gildroy Grant',
#  'Thích Nhất Hạnh',
#  'Herbert Hart (general)',
#  'Erich Hartmann',
#  'Norman Frederick Hastings',
#  'Michael Herrick',
#  'John Hines (Australian soldier)',
#  'Henry de Hinuber',
#  'George Howell (soldier)',
#  'Tim Hughes (soldier)',
#  'Clive Hulme',
#  'Curtis P. Iaukea',
#  'George Ingram',
#  'Clarence Jeffries',
#  'Reginald Judson',
#  'Junayd of Aydın',
#  'George Kenney',
#  'Albert Kesselring',
#  'Ernest J. King',
#  'Howard Kippenberger',
#  "List of Knight's Cross of the Iron Cross recipients (Ha–Hm)",
#  'Stanisław Koniecpolski',
#  'John Kourkouas',
#  'Lâm Văn Phát',
#  'Harry Laurent',
#  'Lê Văn Duyệt',
#  'Philippe Leclerc de Hauteclocque',
#  'Christopher Lekapenos',
#  'Egmont Prinz zur Lippe-Weißenfeld',
#  'Vojislav Lukačević',
#  'Frank Lukis',
#  'Günther Lützow',
#  'George Mackinolty',
#  'Yannis Makriyannis',
#  'William George Malone',
#  'Sam Manekshaw',
#  'Hans-Joachim Marseille',
#  'Joseph Maxwell',
#  'Egon Mayer',
#  'William McAloney',
#  'John S. McCain Jr.',
#  'Lewis McGee (soldier)',
#  'Frederick E. Morgan',
#  'Michael P. Murphy',
#  'Ashot Nadanian',
#  'Napoleon',
#  'Gia Long',
#  'Nguyễn Văn Nhung',
#  'Henry James Nicholas',
#  'John Northcott',
#  'Walter Nowotny',
#  "Flannery O'Connor",
#  'Max-Hellmuth Ostermann',
#  'Keith Park',
#  'Mikhail Petrov (general)',
#  'Witold Pilecki',
#  'Reginald Pinney',
#  'Priscus (magister militum)',
#  'Jack Rae',
#  'Brian Robertson, 1st Baron Robertson of Oakridge',
#  'Horace Robertson',
#  'Sydney Rowell',
#  'Heinrich Prinz zu Sayn-Wittgenstein',
#  'Johann Heinrich von Schmitt',
#  'Heinz-Wolfgang Schnaufer',
#  'Elliot See',
#  'Teddy Sheean',
#  'David M. Shoup',
#  'Colin Hall Simpson',
#  'Annika Sörenstam',
#  'William Stacy',
#  'Percy Statton',
#  'Percy Storkey',
#  'Tetricus I',
#  'Margaret Thatcher',
#  'Ernest Titterton',
#  'Bardanes Tourkos',
#  'Leonard Trent',
#  'John Troglita',
#  'George Alan Vasey',
#  'Vitalian (consul)',
#  'Werner Voss',
#  'Hans Waldmann (fighter pilot)',
#  'James Allen Ward',
#  'Theodor Weissenberger',
#  'Ennis Whitehead',
#  'Wolf-Dietrich Wilcke',
#  'Donald Wilson (general)',
#  'List of World War I aces credited with 5 victories',
#  'Frank Worsley',
#  'Josef Wurmheller',
#  'Paul Wurtsmith',
#  'A-Class biography (actors and filmmakers) articles',
#  'A-Class biography (arts and entertainment) articles',
#  'A-Class biography (core) articles',
#  'A-Class biography (military) articles',
#  'A-Class biography (musicians) articles',
#  'A-Class biography (peerage) articles',
#  'A-Class biography (politics and government) articles',
#  'A-Class biography (royalty) articles',
#  'A-Class biography (science and academia) articles',
#  'A-Class biography (sports and games) articles',
#  'Requests for biography A-Class review',
#  'Napoleon',
#  'Rudolf Abel',
#  "Abu'l-Aswar Shavur ibn Fadl",
#  'Aegidius',
#  'Ahmad ibn Tulun',
#  'Barton S. Alexander',
#  'Leslie Andrew',
#  'Asad ibn Abdallah al-Qasri',
#  'Alexandru Averescu',
#  'Robert Bacher',
#  'Heinrich Bär',
#  'Philip Baxter',
#  'Bessas (magister militum)',
#  'Minden Blake',
#  'Oswald Boelcke',
#  'Norris Bradbury',
#  'Frank Buckles',
#  'Jon Burge',
#  'Roy Burston',
#  'Smedley Butler',
#  'James Cannan',
#  'Arthur S. Carpender',
#  'Jean de Carrouges',
#  'Hugh John Casey',
#  'Bob Chappuis',
#  'Alan Charlesworth',
#  'Johnny Checketts',
#  'Percy Cherry',
#  'Cho Ki-chon',
#  'Wilfred Clouston',
#  'Eileen Collins',
#  'Arthur Compton',
#  'Thomas Cooke (soldier, born 1881)',
#  'Harry Crerar',
#  'James Crichton (soldier)',
#  'Tim Cross',
#  'Michael J. Daly',
#  'Wilbur Dartnell',
#  'Hippolyte De La Rue',
#  'William F. Dean',
#  'Alan Deere',
#  'Léon Degrelle',
#  'Miles Dempsey',
#  'Jacob L. Devers',
#  'Trương Định',
#  'Mato Dukovac',
#  'Robert L. Eichelberger',
#  'Milorad Ekmečić',
#  'Herennius Etruscus',
#  'Eucherius (son of Stilicho)',
#  'Thomas Farrell (United States Army officer)',
#  'Hermann Fegelein',
#  'Samuel Forsyth',
#  'Rudolf Frank',
#  'Samuel Frickleton',
#  'Yuri Gagarin',
#  'Elmer Gedeon',
#  'Germanicus',
#  'Stanley Gibbs',
#  'Gisco (died 239 BC)',
#  'Alexander Godley',
#  'Gordon Gollob',
#  'Hermann Graf',
#  'John Gildroy Grant',
#  'Freddie de Guingand',
#  'Al-Mundhir III ibn al-Harith',
#  'Herbert Hart (general)',
#  'Erich Hartmann',
#  'Lindsay Hassett',
#  'Norman Frederick Hastings',
#  'Michael Herrick',
#  'Robert Peverell Hichens',
#  'John Hines (Australian soldier)',
#  'Henry de Hinuber',
#  'Benjamin Lewis Hodge',
#  'Friedrich Freiherr von Hotze',
#  'George Howell (soldier)',
#  'Tim Hughes (soldier)',
#  'Clive Hulme',
#  'Curtis P. Iaukea',
#  'George Ingram',
#  'Clarence Jeffries',
#  'Reginald Judson',
#  'Junayd of Aydın',
#  'Manuel Kamytzes',
#  'George Kenney',
#  'Albert Kesselring',
#  'Ernest J. King',
#  'Howard Kippenberger',
#  'George Kistiakowsky',
#  "List of Knight's Cross of the Iron Cross recipients (Ha–Hm)",
#  'Stanisław Koniecpolski',
#  'John Kourkouas',
#  'Lâm Văn Phát',
#  'Harry Laurent',
#  'Lê Văn Duyệt',
#  'Philippe Leclerc de Hauteclocque',
#  'Christopher Lekapenos',
#  'Egmont Prinz zur Lippe-Weißenfeld',
#  'Vojislav Lukačević',
#  'Frank Lukis',
#  'Wolfgang Lüth',
#  'Günther Lützow',
#  'Donough MacCarty, 1st Earl of Clancarty',
#  'George Mackinolty',
#  'Yannis Makriyannis',
#  'William George Malone',
#  'Sam Manekshaw',
#  'Hans-Joachim Marseille',
#  'Joseph Maxwell',
#  'Egon Mayer',
#  'William McAloney',
#  'John S. McCain Jr.',
#  'John S. McCain Sr.',
#  'Lewis McGee (soldier)',
#  'Keith Miller',
#  'Walter Model',
#  'Frederick E. Morgan',
#  'Leslie Morshead',
#  'Michael P. Murphy',
#  'Napoleon',
#  'Gia Long',
#  'Nguyễn Văn Nhung',
#  'Henry James Nicholas',
#  'Kenneth Nichols',
#  'Manuel Noriega',
#  'John Northcott',
#  'Walter Nowotny',
#  'Max-Hellmuth Ostermann',
#  'Zaharije Ostojić',
#  'Jean-Baptiste Ouédraogo',
#  'Keith Park',
#  'Mikhail Petrov (general)',
#  'Hans Philipp',
#  'Witold Pilecki',
#  'Reginald Pinney',
#  'E. T. Pollock',
#  'Priscus (magister militum)',
#  'Casimir Pulaski',
#  'Jack Rae',
#  'Helmuth Raithel',
#  'Brian Robertson, 1st Baron Robertson of Oakridge',
#  'Horace Robertson',
#  'Sydney Rowell',
#  'Sasaki Tōichi',
#  'Heinrich Prinz zu Sayn-Wittgenstein',
#  'Johann Heinrich von Schmitt',
#  'Heinz-Wolfgang Schnaufer',
#  'Norman Schwarzkopf Jr.',
#  'Elliot See',
#  'Teddy Sheean',
#  'David M. Shoup',
#  'Colin Hall Simpson',
#  'Walter Bedell Smith',
#  'Spendius',
#  'William Stacy',
#  'Percy Statton',
#  'Staurakios',
#  'Percy Storkey',
#  'Hyacinth Graf Strachwitz',
#  'Teriitaria II',
#  'Tetricus I',
#  'Benjamin Franklin Tilley',
#  'Ernest Titterton',
#  'Bardanes Tourkos',
#  'Leonard Trent',
#  'John Troglita',
#  'Stanisław Ulam',
#  'George Alan Vasey',
#  'Vitalian (consul)',
#  'Werner Voss',
#  'Hans Waldmann (fighter pilot)',
#  'James Allen Ward',
#  'Al-Wathiq',
#  'Theodor Weissenberger',
#  'Military career of Arthur Wellesley, 1st Duke of Wellington',
#  'Ennis Whitehead',
#  'Wolf-Dietrich Wilcke',
#  'Donald Wilson (general)',
#  'List of World War I aces credited with 5 victories',
#  'Frank Worsley',
#  'Josef Wurmheller',
#  'Paul Wurtsmith',
#  'Brian Robertson, 1st Baron Robertson of Oakridge',
#  'Margaret Thatcher',
#  'Cho Ki-chon',
#  'Yannis Makriyannis',
#  "Flannery O'Connor",
#  'Bleeding Through',
#  'Alexandru Averescu',
#  'Curtis P. Iaukea',
#  'Yannis Makriyannis',
#  'William George Malone',
#  'Napoleon',
#  'Gia Long',
#  'Margaret Thatcher',
#  "Abu'l-Aswar Shavur ibn Fadl",
#  'Germanicus',
#  'Gordian dynasty',
#  'Junayd of Aydın',
#  'Stanisław Koniecpolski',
#  'Christopher Lekapenos',
#  'Napoleon',
#  'Gia Long',
#  'Heinrich Prinz zu Sayn-Wittgenstein',
#  'Tetricus I',
#  'A-Class British royalty articles',
#  'A-Class Scottish royalty articles',
#  'Philip Baxter',
#  'Robert L. Eichelberger',
#  ...]

# %%
site = mwclient.Site('en.wikipedia.org', clients_useragent='clip_embedding_wikipedia/0.0 (https://calebkruse.com/; caleb.krs@gmail.com)')

good_article_base = 'Category:A-Class_articles'
# start by getting all categories
categories = []
page = site.pages[good_article_base + '/all']
for line in page.text().split('\n'):
        #print(line)
        if line.startswith('*') and '[[' in line and ']]' in line:
            start = line.find('[[') + 2
            end = line.find(']]')
            category = line[start:end].split('|')[1]
            categories.append(category)

# get all articles in the categories
articles = []
for category in categories:
    page = site.pages[f'{good_article_base}/{category}']
    for line in page.text().split('\n'):
        if '[[' in line and ']]' in line and '|' not in line:
            start = line.find('[[') + 2
            end = line.find(']]')
            article = line[start:end]
            articles.append(article)
# Out:
# 26731

# %%
categories
# Out:
# ['Agriculture, food, and drink',
#  'Art and architecture',
#  'Engineering and technology',
#  'Geography and places',
#  'History',
#  'Language and literature',
#  'Mathematics',
#  'Media and drama',
#  'Music',
#  'Natural sciences',
#  'Philosophy and religion',
#  'Social sciences and society',
#  'Sports and recreation',
#  'Video games',
#  'Warfare']

# %%
articles = []
page = site.pages['Wikipedia:Good articles/Agriculture, food and drink']
for line in page.text().split('\n'):
    #print(line)
    if '[[' in line and ']]' in line and '|' not in line:
        start = line.find('[[') + 2
        end = line.find(']]')
        article = line[start:end]
        articles.append(article)
        
print(articles)
# Out:
# ['Agriculture', 'Agriculture in Turkey', 'Agriculture in Wales', 'Animal husbandry', 'Apiary Laboratory', 'Aquaculture in the Philippines', 'Arab Agricultural Revolution', 'Avondale Agricultural Research Station', 'Belted Galloway', 'Biological pest control', 'Bitter orange', 'Boreray sheep', 'Briarcliff Farms', 'Cattle', 'Chicken', 'Citrus', 'Cocoa production in São Tomé and Príncipe', 'Columbian exchange', 'Companion planting', 'Coon hunting', 'Cotton production in Pakistan', 'Cowpea', 'Cow tipping', 'Crop diversity', 'Dairy in India', 'Domestic duck', 'Domestic rabbit', 'Domestication', 'Domestication of the sheep', 'Fisheries in the Philippines', 'Galloway cattle', 'Goat', 'Goat tower', 'Hemp in Kentucky', 'Highland cattle', 'History of agriculture', 'Lemon', 'Locust Plague of 1874', 'Mandarin orange', 'North American Piedmontese', 'Oat', 'Pekarangan', 'Permaculture', 'Pest control', 'Pig', 'Polled Dorset', 'Polyculture', 'Poultry', 'Quince', 'Rice-fish system', 'Rye', 'Sesame', 'Shetland sheep', 'Spelt', 'Strawberry', 'Sweet potato cultivation in Polynesia', 'Tennessee Walking Horse National Celebration', 'Tomato', 'Vanilla production in French Polynesia', 'Vegetable', 'Welsh Pony and Cob', 'Wisconsin dairy industry', 'Woollen industry in Wales', 'Beaver drop', 'Cherry blossom', 'Cornell Botanic Gardens', 'Cottage garden', 'Forests in Turkey', 'George Willis Pack', 'Green Guerillas', 'Oroblanco', '5-8 Club', "Amal Women's Training Center and Moroccan Restaurant", 'Argo Tea', 'Arleta Library Bakery & Cafe', "Bailey's Taproom", 'Barracuda Lounge', "Bernstein's Bagels", 'The Bigg Chill', 'Bipartisan Cafe', 'Bistro Agnes', 'Bit House Saloon', 'Black Cat Bar', 'Bluehour', 'Blueplate Lunch Counter and Soda Fountain', 'Boloco', 'Bonnie Blue Southern Market & Bakery', 'Booches', 'The Box Tree', 'Boxer Ramen', 'Boxers NYC Washington Heights', 'Bridges Cafe', 'Brix Tavern', 'Burger King', 'Byways Cafe', 'Capitol Hill mystery soda machine', 'Chatterbox (restaurant)', 'The Checkers (restaurant)', 'Club Cumming', 'Club Feathers', 'Cocina de Autor', 'The Cock', 'The Comeback Seattle', "Country Bill's", 'Cricket Cafe', 'Davis Street Tavern', 'Delta Cafe', 'Dime Store (Portland, Oregon)', 'Dinner by Heston Blumenthal', 'DTM (nightclub)', 'Eagle Boys', 'El Celler de Can Roca', 'Em (restaurant)', "Esparza's", 'Esquina Común', 'The Fat Duck', "Fat's Chicken and Waffles", 'Four Seasons Restaurant', "Fuller's Coffee Shop", 'Gage and Tollner', 'Georgies', 'Ghost Alley Espresso', 'Gordon Ramsay Plane Food', "Graeter's", 'Gypsy Restaurant and Velvet Lounge', 'Headroom LGBTQ+ Lounge', 'Henry Higgins Boiled Bagels', 'Hercules (nightclub)', 'Hershey Creamery Company', 'Hibiscus (restaurant)', 'History of Burger King', 'History of KFC', "Hobo's", "Hodad's", 'Holy Trinity Barbecue', 'Imperial Bottle Shop & Taproom', 'Industry Bar', "Jeff's Gourmet Sausage Factory", "Joe Brown's Carmel Corn", 'Keweenaw Brewing Company', 'KFC', 'Kissa Tanto', 'La Bonita', 'La Caravelle (New York City)', 'La Carreta Mexican Restaurant', 'La Tante DC10 Restaurant', 'Last Exit on Brooklyn', "Leonard's Bakery", 'The Liquor Store', 'Los Pollos Hermanos', "Lundy's Restaurant", 'Lutz Tavern', 'Masia (restaurant)', 'Metrovino', 'MidCity SmashedBurger', 'Miran Pastourma', "Mzoli's", 'Noodles & Company', 'Nostrana (restaurant)', 'Ordinaire (wine bar)', 'Ore Dock Brewing Company', 'The Original Dinerant', "Papi Chulo's", 'Paradise (nightclub)', 'The Parish', 'Park Grill', 'PDX671', 'Pearl Tavern', "Pearson's Candy Company", 'Pied Cow Coffeehouse', 'Pike Place Fish Market', 'Pujol (restaurant)', 'Purr Cocktail Lounge', 'Pétrus (restaurant)', 'The Q (nightclub)', "The Queen's Head (Portland, Oregon)", 'Quintonil', 'Rainbow Room', 'Rancho Bravo Tacos', 'Regent Bakery and Cafe', 'Republic Cafe and Ming Lounge', 'The Restaurant Marco Pierre White', 'Rimsky-Korsakoffee House', 'Rise Bar', 'Ristorante Machiavelli', 'Roman Candle (Portland, Oregon)', 'Rosetta (restaurant)', 'The Roxy (Po ...

# %%
import mwclient
import re
from time import sleep

def get_good_articles():
    # Connect to English Wikipedia
    site = mwclient.Site('en.wikipedia.org')
    
    # Dictionary to store articles by category
    articles_by_category = {}
    
    # List of all category pages that contain good articles
    category_pages = [
        'Wikipedia:Good articles/Agriculture, food and drink',
        'Wikipedia:Good articles/Art and architecture',
        'Wikipedia:Good articles/Engineering and technology',
        'Wikipedia:Good articles/Geography and places',
        'Wikipedia:Good articles/History',
        'Wikipedia:Good articles/Language and literature',
        'Wikipedia:Good articles/Mathematics, science, and technology',
        'Wikipedia:Good articles/Media and drama',
        'Wikipedia:Good articles/Music',
        'Wikipedia:Good articles/Natural sciences',
        'Wikipedia:Good articles/Philosophy and religion',
        'Wikipedia:Good articles/Social sciences and society',
        'Wikipedia:Good articles/Sports and recreation',
        'Wikipedia:Good articles/Video games',
        'Wikipedia:Good articles/Warfare'
    ]
    
    def extract_articles_from_text(text):
        # Regular expression to find article links, excluding categories and templates
        # Look for lines that start with * or # followed by a link
        article_pattern = r'[\*#]\s*\[\[([^]|]+?)(?:\|[^]]+)?\]\]'
        matches = re.finditer(article_pattern, text)
        
        articles = []
        for match in matches:
            title = match.group(1)
            # Skip Wikipedia: namespace and other special pages
            if not any(title.startswith(prefix) for prefix in ['Wikipedia:', 'Template:', 'Category:', 'Portal:']):
                articles.append(title)
        return articles
    
    # Process each category page
    for category_page_title in category_pages:
        try:
            print(f"Processing {category_page_title}...")
            page = site.pages[category_page_title]
            text = page.text()
            print(text)
            
            # Extract articles from this category
            category_articles = extract_articles_from_text(text)
            
            # Store articles under the category name (removing the prefix)
            category_name = category_page_title.replace('Wikipedia:Good articles/', '')
            articles_by_category[category_name] = category_articles
            
            # Be nice to Wikipedia's servers
            sleep(1)
            
        except Exception as e:
            print(f"Error processing {category_page_title}: {e}")
    
    return articles_by_category

def main():
    try:
        articles_by_category = get_good_articles()
        print(articles_by_category)
        
        # Print summary and save results
        total_articles = sum(len(articles) for articles in articles_by_category.values())
        print(f"\nFound {total_articles} good articles across {len(articles_by_category)} categories:")
        
    except Exception as e:
        print(f"An error occurred: {e}")


main()
# Out:
# Processing Wikipedia:Good articles/Agriculture, food and drink...
# <noinclude>
# {{Wikipedia:Good article nominations/Tab header}}
# <div class="mw-collapsible mw-collapsed">
# {{Wikipedia:Good articles/Summary|shortcuts={{shortcut|WP:GA/AF}}}}
# </div></noinclude><templatestyles src="Wikipedia:Good articles/styles.css"/>
# __NOTOC__
# <div class="wp-ga-topic">
# <noinclude>
# ==GA==
# {{Wikipedia:Good articles/GA topic header}}</noinclude>
# ==Agriculture, food, and drink==
# <includeonly><div class="wp-ga-topic-back">[[#Contents|back]]</div></includeonly>
# <!--Start Agriculture, food, and drink level 3 GA subtopic-->
# <div class="mw-collapsible">
#
# ===[[File:Tango icon nature.svg|22px|left|link=|alt=]] Agriculture, food, and drink===
# <div class="mw-collapsible-content">
#
# =====Agriculture and farming=====
# {{#invoke:Good Articles|subsection|
# [[Agriculture]]
# [[Agriculture in Turkey]]
# [[Agriculture in Wales]]
# [[Animal husbandry]]
# [[Apiary Laboratory]]
# [[Aquaculture in the Philippines]]
# [[Arab Agricultural Revolution]]
# [[Avondale Agricultural Research Station]]
# [[Belted Galloway]]
# [[Biological pest control]]
# [[Bitter orange]]
# [[Boreray sheep]]
# [[Briarcliff Farms]]
# [[Cattle]]
# [[Chicken]]
# [[Citrus]]
# [[Cocoa production in São Tomé and Príncipe]]
# [[Columbian exchange]]
# [[Companion planting]]
# [[Coon hunting]]
# [[Cotton production in Pakistan]]
# [[Cowpea]]
# [[Cow tipping]]
# [[Crop diversity]]
# [[Dairy in India]]
# [[Domestic duck]]
# [[Domestic rabbit]]
# [[Domestication]]
# [[Domestication of the sheep]]
# [[Fisheries in the Philippines]]
# [[Galloway cattle]]
# [[Goat]]
# [[Goat tower]]
# <noinclude>
# ===Back===
# <div class="wp-ga-topic-back">[[#GA|back]]</div>
# </div>
# [[Category:Lists of good articles|Agriculture, food and drink]]
# </noinclude>
# Processing Wikipedia:Good articles/Art and architecture...
# <noinclude>
# {{Wikipedia:Good article nominations/Tab header}}
# </div><div class="mw-collapsible mw-collapsed">
# {{Wikipedia:Good articles/Summary|shortcuts={{shortcut|WP:GA/AA}}}}
# </div></noinclude><templatestyles src="Wikipedia:Good articles/styles.css"/>
# __NOTOC__
# <div class="wp-ga-topic">
# <noinclude>
# ==GA==
# {{Wikipedia:Good articles/GA topic header}}</noinclude>
# ==Art and architecture==
# <includeonly><div class="wp-ga-topic-back">[[#Contents|back]]</div></includeonly>
# <div class="wp-ga-topic-contents">
# ===Contents===
# {{plainlist}}
# * [[#Art|Art]]
# * [[#Architecture|Architecture]]
# {{endplainlist}}
# </div>
# <!--Start Art level 3 GA subtopic-->
# <div class="mw-collapsible">
#
# ===[[File:Nuvola apps package graphics.svg|22px|left|alt=|link=]] Art===
# <div class="wp-ga-topic-back">[[#Art and architecture|back]]</div>
# <div class="mw-collapsible-content">
# <!--The level 5 GA subtopics on this page may be first subdivided into new level 4 GA subtopics; see other GA topic pages-->
# <!--The level 5 GA subtopics on this page may be subdivided into new level 5 GA subtopics and other level 5 GA subtopics may be added; see other GA topic pages-->
#
# ====Art====
# {{#invoke:Good Articles|subsection|
# [[Abel Tasman Monument]]
# [[Akzidenz-Grotesk]]
# [[Albert Pike Memorial]]
# [[Allow Me (Portland, Oregon)|''Allow Me'' (Portland, Oregon)]]
# [[Alma Mater (New York sculpture)|''Alma Mater'' (New York sculpture)]]
# ''[[Angel of the North]]''
# ''[[Angkor I]]''
# [[Angolan pavilion]]
# [[Antarctic Treaty issue]]
# ''[[Antimonumento 5J]]''
# [[Armenian illuminated manuscripts]]
# [[Art in early modern Scotland]]
# [[Art in Medieval Scotland]]
# [[Art in modern Scotland]]
# ''[[B of the Bang]]''
# [[Art of Francisco Narváez in the University City of Caracas]]
# ''[[Babe Ruth Bows Out]]''
# [[Bara (genre)|''Bara'' (genre)]]
# [[Barack Obama "Hope" poster]]
# [[Batik]]
# [[Bed hangings]]
# [[Bembo]]
# ''[[Better Out Than In]]''
# [[Birds' Head Haggadah]]
# [[Bliss (photograph)|''Bliss'' (photograph)]]
# [[Bois Protat]]
# [[Bookwheel]]
# [[Brushstrokes series]]
# [[Burnside Fountain]]
# [[Canons of page construction]]
# [[Chain Reaction (sculpture)|''Chain Reaction'' (sculpture)]]
# [[Changi Murals]]
# [[Comedian (artwork)|''Comedian'' (artwork)]]
# ''[[Conductores de Venezuela]]''
# ''[[Confederate Defenders of Charleston]]''
# ''[[Coraline's Curious Cat Trail]]''
# [[Corleck Head]]
# ''[[Cottontail on the Trail]]''
# [[Court of Neptune Fountain]]
# [[Crosby Garrett Helmet]]
# [[Cueva de las Manos]]
# [[Cup of the Ptolemies]]
# [[David of Sassoun (statue)|''David of Sassoun'' (statue)]]
# ''[[Demi's Birthday Suit]]''
# [[Mukilteo, Washington]]
# [[Near South Side, Chicago]]
# [[Newark, New Jersey]]
# [[Norman, Oklahoma]]
# [[North Potomac, Maryland]]
# [[Oak Lawn (Washington, D.C.)]]
# [[Old Louisville]]
# [[Omak, Washington]]
# [[Oregon and California Railroad Revested Lands]]
# [[Palm Beach, Florida]]
# [[Perry County, Tennessee]]
# [[Pierson, Iowa]]
# [[Point Loma, San Diego]]
# [[Ponce de Leon Springs (Atlanta)]]
# [[Pullman Square]]
# [[Randolph, Tennessee]]
# [[Riley's Lock]]
# [[River Oaks, Houston]]
# [[Riverside and Avondale]]
# [[Roanoke, Virginia]]
# [[Robeson County, North Carolina]]
# [[Rodney, Mississippi]]
# [[Rosendale (CDP), New York]]
# [[Rush Street (Chicago)]]
# [[Saint Paul, Minnesota]]
# [[San Diego]]
# [[San Francisco Bay Area]]
# [[San Marco (Jacksonville)]]
# [[Sarnia]]
# [[Scotland County, North Carolina]]
# [[Seneca Village]]
# [[Shawnee on Delaware, Pennsylvania]]
# [[Sheet Harbour, Nova Scotia]]
# [[Silver Reef, Utah]]
# [[Smith–Harris House (East Lyme, Connecticut)]]
# [[Smuggler's Gulch]]
# [[Snyder, New York]]
# [[South Dakota]]
# [[South End–Groesbeckville Historic District]]
# [[South Jordan, Utah]]
# [[Spokane, Washington]]
# [[Spring Creek, Brooklyn]]
# [[Stanwood, Washington]]
# [[Starrett City]]
# [[Streeterville]]
# [[Sultan, Washington]]
# [[Sunset Park, Brooklyn]]
# [[Teaneck, New Jersey]]
# [[Tennessee]]
# [[Utica, New York]]
# [[Valley, West Virginia]]
# [[Virginia Beach, Virginia]]
# [[Wallkill Valley Rail Trail]]
# [[Washington Heights, Chicago]]
# [[Washington Heights, Manhattan]]
# [[Washington Park Historic District (Albany, New York)]]
# [[Washington Park (community area), Chicago]]
# [[Wilsonville, Oregon]]
# [[Wolf Point, Chicago]]
# [[Yaanga]]
# [[Yonkers, New York]]
# }}
#
# =====South America=====
# <!--Includes only cities, towns, neighborhoods, states, provinces, counties, and other subnational political designations.  Other locations belong somewhere else-->
# {{#invoke:Good Articles|subsection|
# [[Pichilemu]]
# }}
#
# </div>
# </div><!--End Places level 3 GA subtopic-->
# <noinclude>
# ===Back===
# <div class="wp-ga-topic-back">[[#GA|back]]</div>
# </div>
# [[Category:Lists of good articles|Geography]]
# </noinclude>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[31], line 81
#      77     except Exception as e:
#      78         print(f"An error occurred: {e}")
# ---> 81 main()
#
# Cell In[31], line 70, in main()
#      68 def main():
#      69     try:
# ---> 70         articles_by_category = get_good_articles()
#      71         print(articles_by_category)
#      73         # Print summary and save results
#
# Cell In[31], line 61, in get_good_articles()
#      58     articles_by_category[category_name] = category_articles
#      60     # Be nice to Wikipedia's servers
# ---> 61     sleep(1)
#      63 except Exception as e:
#      64     print(f"Error processing {category_page_title}: {e}")
#
# KeyboardInterrupt:

# %%
# Access Wikipedia fetcher directly
wiki_fetcher = orchestrator.wiki_fetcher
vital_articles = wiki_fetcher.get_vital_articles(level=3)

vital_articles[:10]
